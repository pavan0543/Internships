# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = "C:\\Users\\sures\\OneDrive\\Documents\\Data Science\\Data Sets\\cognifyz dataset.csv"
df = pd.read_csv(file_path)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
df.size
# Out:
# 200571

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
cat = df.select_dtypes(include=['object']).columns
num = df.select_dtypes(exclude = ['object']).columns
print("cat :",cat)
print("num :",num)
# Out:
# cat : Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Rating color',
#        'Rating text'],
#       dtype='object')
# num : Index(['Restaurant ID', 'Country Code', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'],
#       dtype='object')

# %%
df["Cuisines"]=df['Cuisines'].fillna(df['Cuisines'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# **LEVEL-1**
#
#
#   $Task-1$

# %% [markdown]
# - determine the top three cuisines column

# %%
df["Cuisines"].values
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Italian, World Cuisine',
#        'Restaurant Cafe', 'Cafe'], dtype=object)

# %%
top_three = df['Cuisines'].value_counts().head(3)
top_three
# Out:
# Cuisines
# North Indian             945
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
print("The Top Three Cuisines ")

for i in range(len(top_three.index)):
    print(top_three.index[i])
# Out:
# The Top Three Cuisines
# North Indian
# North Indian, Chinese
# Chinese

# %%
top_three.keys()
# Out:
# Index(['North Indian', 'North Indian, Chinese', 'Chinese'], dtype='object', name='Cuisines')

# %%
plt.figure(figsize = (5,5))
color = ["green","red",'yellow']
top_three.plot(kind = 'bar',color = color)
plt.title("Top three Cuisines")
plt.xlabel("Cuisines")
plt.ylabel("Number of Restaurents")
plt.show()

# %% [markdown]
# **Calculate the percentage of restaurents that serves the top three cuisines**

# %%
total_restaurents = len(df)

# %%
Percentage = (top_three.values/total_restaurents)*100
Percentage
# Out:
# array([9.89425191, 5.35022511, 3.70641818])

# %%
data = dict(zip(top_three.index,Percentage))
data
# Out:
# {'North Indian': 9.894251910794681,
#  'North Indian, Chinese': 5.350225107318606,
#  'Chinese': 3.706418176107214}

# %%
a = pd.DataFrame(zip(top_three.index,Percentage),columns=["Cuisines","Percentage"])
a
# Out:
#                 Cuisines  Percentage
# 0           North Indian    9.894252
# 1  North Indian, Chinese    5.350225
# 2                Chinese    3.706418

# %%
#plt.bar(x = "Cuisines",height = "Percentage",data = a)
# a.plot(kind = 'bar')

# %%
 plt.pie(a['Percentage'],labels = a["Cuisines"],autopct='%0.2f%%',explode = [0.05,0.05,0.05],startangle=90)
plt.show()

# %% [markdown]
# **Task-2**
#  - Identify the city with the highest number of restaurents in the data sets

# %%
city = df['City'].value_counts()

# %%
print("The city with highest number of restaurents ")
city.index[0]
# Out:
# The city with highest number of restaurents
# 'New Delhi'

# %% [markdown]
# - Calculate the avg rating for restaurents in each city

# %%
df["City"].nunique()
# Out:
# 141

# %%
mean = df['Aggregate rating'].mean()
mean
# Out:
# 2.66637001361114

# %%
avg_rating = df.groupby('City')['Aggregate rating'].mean().reset_index(),ascending = False
avg_rating
# Out:
#                 City  Aggregate rating
# 0          Abu Dhabi          4.300000
# 1               Agra          3.965000
# 2          Ahmedabad          4.161905
# 3             Albany          3.555000
# 4          Allahabad          3.395000
# ..               ...               ...
# 136          Weirton          3.900000
# 137  Wellington City          4.250000
# 138   Winchester Bay          3.200000
# 139          Yorkton          3.300000
# 140        ��stanbul          4.292857
#
# [141 rows x 2 columns]

# %% [markdown]
# - Determine the city with the highest average rating

# %%
print("The city with the highest average rating :")
avg_rating.index[0]
# Out:
# The city with the highest average rating :
# 'Abu Dhabi'

# %%
avg_rating_city = avg_rating.sort_values(by="Aggregate rating",ascending=False)
avg_rating_city
# Out:
#                  City  Aggregate rating
# 56         Inner City          4.900000
# 107       Quezon City          4.800000
# 73        Makati City          4.650000
# 95         Pasig City          4.633333
# 75   Mandaluyong City          4.625000
# ..                ...               ...
# 88          New Delhi          2.438845
# 83          Montville          2.400000
# 78          Mc Millan          2.400000
# 89              Noida          2.036204
# 43          Faridabad          1.866932
#
# [141 rows x 2 columns]

# %%
avg_rating_city.iloc[0,0]
# Out:
# 'Inner City'

# %% [markdown]
# **Task-3**
#
#  - Create a histogram or bar chart to visualize the distribution of price ranges among the restaurents

# %%
a=df["Price range"].value_counts()

# %%
plt.bar(x = ['1','2','3','4'],height = df["Price range"].value_counts(),color = ["Blue","orange","red","pink"])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
#  - Calculate the percentage of restaurents in each price range category

# %%
y=df["Price range"].value_counts()
y
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
b=len(df)

# %%
percentage = round((y/b)*100,2)
percentage
# Out:
# Price range
# 1    46.53
# 2    32.59
# 3    14.74
# 4     6.14
# Name: count, dtype: float64

# %%
data = pd.DataFrame(percentage)
data
# Out:
#              count
# Price range
# 1            46.53
# 2            32.59
# 3            14.74
# 4             6.14

# %% [markdown]
# **Task-4**
#  - Determine the percentage of restaurents that offer online delivery

# %%
c=len(df[df["Has Online delivery"]=='Yes'].value_counts())
c
# Out:
# 2451

# %%
per = round((c/len(df))*100,2)
per
# Out:
# 25.66

# %% [markdown]
# - Compare the avg rating of restaurent with and without online delivery

# %%
df.groupby("Has Online delivery")['Aggregate rating'].mean().round(2).reset_index()
# Out:
#   Has Online delivery  Aggregate rating
# 0                  No              2.47
# 1                 Yes              3.25
